# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_file = 'chaplinfilter/Data/jitterdata_box4_110818.txt'
df = pd.read_csv(data_file, sep='\s+')
df.head()
# Out:
#    Mass    Radius     Teff   logg         L      tp1      tpE
# 0   0.7  0.665300  4365.16  4.639  0.141254  1.85206  1.85206
# 1   0.7  0.683152  4405.55  4.616  0.155239  2.00248  1.85206
# 2   0.7  0.703911  4466.84  4.590  0.172982  2.24105  1.85206
# 3   0.8  0.718644  4797.33  4.630  0.240991  2.32450  1.95894
# 4   0.8  0.742187  4841.72  4.602  0.266686  2.56489  2.23384

# %%
fig, ax = plt.subplots()
ax.scatter(df.Teff, df.Radius, c=df.Mass, cmap='viridis')
ax.set_xlim([7500, 4000])
plt.show()

# %%
sns.pairplot(df)
